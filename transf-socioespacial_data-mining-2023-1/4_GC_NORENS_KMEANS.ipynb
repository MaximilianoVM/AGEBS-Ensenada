# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans

# %matplotlib inline

# %% [markdown]
# traemos los datos de github

# %%
url10 = 'DATA/4_NORENS_AGEBS_10.csv'
url20 = 'DATA/4_NORENS_AGEBS_20.csv'

ens10 = pd.read_csv(url10)
ens20 = pd.read_csv(url20)

# %%
ens10.head(2)
# Out:
#    AGEB  P_TOTAL  POB65_MAS  GRAPROES  PROM_HNV  VIVTOT  PRO_OCUP_C  \
# 0  0435   3632.0      325.0  9.617302  2.193333  1321.0    0.853016
# 1  044A   1539.0      224.0  9.569643  2.264286   549.0    0.750714
#
#    PROM_OCUP  VPH_PC  OTRAENT  P_0A5
# 0   3.352540   584.0   1241.0  419.0
# 1   3.152143   254.0    478.0  135.0

# %% [markdown]
# # PREPARANDO DATOS PARA EL PROCEDIMIENTO

# %% [markdown]
# ordenamos por poblacion total 'P_TOTAL'

# %%
ens10 = ens10.sort_values(by='P_TOTAL', ascending=False).reset_index(drop=True)
ens20 = ens20.sort_values(by='P_TOTAL', ascending=False).reset_index(drop=True)

# %%
ens10.head(5)
# Out:
#    AGEB  P_TOTAL  POB65_MAS   GRAPROES  PROM_HNV  VIVTOT  PRO_OCUP_C  \
# 0  6006   5443.0      225.0   8.844595  2.155405  1581.0    0.993784
# 1  0435   3632.0      325.0   9.617302  2.193333  1321.0    0.853016
# 2  0524   3040.0      276.0   9.127049  2.500164  1083.0    0.816885
# 3  1005   2987.0        4.0  11.066000  1.524500  1228.0    0.829500
# 4  7714   2879.0      172.0   8.219375  2.270313   905.0    0.869375
#
#    PROM_OCUP  VPH_PC  OTRAENT  P_0A5
# 0   3.735405   624.0   1987.0  548.0
# 1   3.352540   584.0   1241.0  419.0
# 2   3.296066   497.0   1074.0  364.0
# 3   3.247000   423.0   1286.0  483.0
# 4   3.345625   329.0   1057.0  367.0

# %% [markdown]
# quitamos AGEB para el clustering

# %%
ens10_vars = ens10.drop(columns='AGEB')
ens20_vars = ens20.drop(columns='AGEB')

# %%
ens10_vars.head(2)
# Out:
#    P_TOTAL  POB65_MAS  GRAPROES  PROM_HNV  VIVTOT  PRO_OCUP_C  PROM_OCUP  \
# 0   5443.0      225.0  8.844595  2.155405  1581.0    0.993784   3.735405
# 1   3632.0      325.0  9.617302  2.193333  1321.0    0.853016   3.352540
#
#    VPH_PC  OTRAENT  P_0A5
# 0   624.0   1987.0  548.0
# 1   584.0   1241.0  419.0

# %% [markdown]
# info

# %%
ens10_vars.describe()
# Out:
#            P_TOTAL   POB65_MAS   GRAPROES   PROM_HNV       VIVTOT  PRO_OCUP_C  \
# count    33.000000   33.000000  33.000000  33.000000    33.000000   33.000000
# mean   1958.545455  154.424242  10.133857   1.847100   726.030303    0.753368
# std     956.946351  102.447252   1.871146   0.367036   309.561533    0.195327
# min     557.000000    0.000000   6.204906   0.912826   281.000000    0.372609
# 25%    1303.000000   59.000000   9.127049   1.524500   542.000000    0.618846
# 50%    1774.000000  172.000000  10.083929   1.911667   679.000000    0.750714
# 75%    2367.000000  225.000000  11.066000   2.155405   903.000000    0.853016
# max    5443.000000  325.000000  14.026154   2.500164  1581.000000    1.228039
#
#        PROM_OCUP      VPH_PC     OTRAENT       P_0A5
# count  33.000000   33.000000    33.00000   33.000000
# mean    3.038960  347.303030   717.00000  208.060606
# std     0.408365  150.307286   350.00875  133.124223
# min     1.648261   95.000000   271.00000   20.000000
# 25%     2.876042  209.000000   471.00000  118.000000
# 50%     3.057955  329.000000   680.00000  152.000000
# 75%     3.293214  438.000000   873.00000  312.000000
# max     3.735405  673.000000  1987.00000  548.000000

# %% [markdown]
# notamos que los datos varian muchisimo en rango entre si, vamos a normalizar de 0 a 1

# %% [markdown]
# ## Normalizamos

# %% [markdown]
# ==> Min-Max Scaling

# %%
from sklearn.preprocessing import MinMaxScaler
scalerMm = MinMaxScaler()

#10
normalizedMm_data10 = scalerMm.fit_transform(ens10_vars)
ens10_normMm = pd.DataFrame(normalizedMm_data10, columns=ens10_vars.columns)

#20
normalizedMm_data20 = scalerMm.fit_transform(ens20_vars)
ens20_normMm = pd.DataFrame(normalizedMm_data20, columns=ens20_vars.columns)


ens10_normMm.head(5)
# Out:
#     P_TOTAL  POB65_MAS  GRAPROES  PROM_HNV    VIVTOT  PRO_OCUP_C  PROM_OCUP  \
# 0  1.000000   0.692308  0.337502  0.782807  1.000000    0.726155   1.000000
# 1  0.629349   1.000000  0.436298  0.806701  0.800000    0.561597   0.816560
# 2  0.508187   0.849231  0.373616  1.000000  0.616923    0.519360   0.789502
# 3  0.497339   0.012308  0.621524  0.385346  0.728462    0.534107   0.765993
# 4  0.475235   0.529231  0.257564  0.855197  0.480000    0.580721   0.813247
#
#      VPH_PC   OTRAENT     P_0A5
# 0  0.915225  1.000000  1.000000
# 1  0.846021  0.565268  0.755682
# 2  0.695502  0.467949  0.651515
# 3  0.567474  0.591492  0.876894
# 4  0.404844  0.458042  0.657197

# %% [markdown]
# ==> Z-Score Standardization

# %%
from sklearn.preprocessing import StandardScaler
scalerZ = StandardScaler()

normalizedZ_data10 = scalerZ.fit_transform(ens10_vars)
ens10_normZ = pd.DataFrame(normalizedZ_data10, columns=ens10_vars.columns)

normalizedZ_data20 = scalerZ.fit_transform(ens20_vars)
ens20_normZ = pd.DataFrame(normalizedZ_data20, columns=ens20_vars.columns)

ens10_normZ.head(3)
# Out:
#     P_TOTAL  POB65_MAS  GRAPROES  PROM_HNV    VIVTOT  PRO_OCUP_C  PROM_OCUP  \
# 0  3.697679   0.699580 -0.699706  0.853011  2.804695    1.249920   1.731890
# 1  1.775858   1.690826 -0.280344  0.957949  1.951775    0.518068   0.779797
# 2  1.147632   1.205115 -0.546413  1.806878  1.171025    0.330225   0.639359
#
#      VPH_PC   OTRAENT     P_0A5
# 0  1.869418  3.684740  2.593143
# 1  1.599170  1.520318  1.609098
# 2  1.011381  1.035789  1.189545

# %% [markdown]
# #CUSTERING

# %% [markdown]
# ## cantidad optima de clusters?

# %% [markdown]
# Codo de Jambú (Elbow Method)

# %%
wcss = []

for i in range(1, 16): 
  kmeans = KMeans(n_clusters=i , max_iter=300)
  #para esto solo necesitamos un censo
  kmeans.fit(ens10_normMm) #aplicamos kmeans al censo 2010
  wcss.append(kmeans.inertia_)

# %%
#graficando los resultados del wcss para formar el codo de jambu
plt.plot(range(1,16) , wcss)
plt.title('codo de jambu')
plt.xlabel('numero de clusters')
plt.ylabel('WCSS') #WCSS es un indicador de que tan similares son los individuos dentro de los clusters

plt.show()

# %% [markdown]
# ## K-MEANS

# %% [markdown]
# utilizaremos 6 clusters, un poco por lo indicado con el codo de jambu, pero mas que nada porque en el articulo de referencia se divide la tipologia de AGEBS en 6

# %% [markdown]
# ### al censo 2010

# %%
clustering10 = KMeans(n_clusters=6, max_iter=300) #crea el modelo
clustering10.fit(ens10_normMm) #aplica el metodo al censo 2010
# Out:
# KMeans(n_clusters=6)

# %% [markdown]
# agregamos la clasificacion al dataframe original de 2010 (ens10)

# %%
ens10['KMeans_Clusters'] = clustering10.labels_ #los resultados del clustering se guardan en labels_ dentro del modelo

ens10.head(3)
# Out:
#    AGEB  P_TOTAL  POB65_MAS  GRAPROES  PROM_HNV  VIVTOT  PRO_OCUP_C  \
# 0  6006   5443.0      225.0  8.844595  2.155405  1581.0    0.993784
# 1  0435   3632.0      325.0  9.617302  2.193333  1321.0    0.853016
# 2  0524   3040.0      276.0  9.127049  2.500164  1083.0    0.816885
#
#    PROM_OCUP  VPH_PC  OTRAENT  P_0A5  KMeans_Clusters
# 0   3.735405   624.0   1987.0  548.0                5
# 1   3.352540   584.0   1241.0  419.0                5
# 2   3.296066   497.0   1074.0  364.0                5

# %% [markdown]
# que agebs estan juntos ?

# %%
#clust10 = ens10.pivot(columns='KMeans_Clusters', values='AGEB').fillna(0)

# Assuming you have a DataFrame called 'df'
cluster10_0 = ens10['AGEB'][ens10['KMeans_Clusters'] == 0].tolist()
cluster10_1 = ens10['AGEB'][ens10['KMeans_Clusters'] == 1].tolist()
cluster10_2 = ens10['AGEB'][ens10['KMeans_Clusters'] == 2].tolist()
cluster10_3 = ens10['AGEB'][ens10['KMeans_Clusters'] == 3].tolist()
cluster10_4 = ens10['AGEB'][ens10['KMeans_Clusters'] == 4].tolist()
cluster10_5 = ens10['AGEB'][ens10['KMeans_Clusters'] == 5].tolist()

# %% [markdown]
# ### al censo 2020

# %%
clustering20 = KMeans(n_clusters=6, max_iter=300) #crea el modelo
clustering20.fit(ens20_normMm) #aplica el metodo al censo 2010
# Out:
# KMeans(n_clusters=6)

# %% [markdown]
# agregamos la clasificacion al dataframe original de 2020 (ens20)

# %%
ens20['KMeans_Clusters'] = clustering20.labels_ #los resultados del clustering se guardan en labels_ dentro del modelo

ens20.head(5)
# Out:
#    AGEB  P_TOTAL  POB65_MAS   GRAPROES  PROM_HNV  VIVTOT  PRO_OCUP_C  \
# 0  6006   4685.0      397.0   9.555526  2.025000  1719.0    0.810000
# 1  0435   3798.0      457.0  10.768983  1.982203  1382.0    0.776610
# 2  1005   3611.0      121.0  11.394000  1.596000  1161.0    0.892667
# 3  7752   2940.0      326.0  10.683235  1.795882  1151.0    0.742941
# 4  7714   2885.0      295.0   9.091176  1.963529   982.0    0.746765
#
#    PROM_OCUP  VPH_PC  OTRAENT  P_0A5  KMeans_Clusters
# 0   3.088684   685.0   1327.0  435.0                3
# 1   3.137627   782.0   1273.0  259.0                3
# 2   3.397333   655.0   1379.0  386.0                5
# 3   2.949706   583.0    754.0  264.0                5
# 4   2.886471   444.0    944.0  283.0                5

# %% [markdown]
# que agebs estan juntos?

# %%
# Assuming you have a DataFrame called 'df'
cluster20_0 = ens20['AGEB'][ens20['KMeans_Clusters'] == 0].tolist()
cluster20_1 = ens20['AGEB'][ens20['KMeans_Clusters'] == 1].tolist()
cluster20_2 = ens20['AGEB'][ens20['KMeans_Clusters'] == 2].tolist()
cluster20_3 = ens20['AGEB'][ens20['KMeans_Clusters'] == 3].tolist()
cluster20_4 = ens20['AGEB'][ens20['KMeans_Clusters'] == 4].tolist()
cluster20_5 = ens20['AGEB'][ens20['KMeans_Clusters'] == 5].tolist()

# %% [markdown]
# ### visualizacion de clusters

# %% [markdown]
# Aplicaremos el analisis de componentes principales para darnos una idea de como se formaron los clusters

# %%
from sklearn.decomposition import PCA

# %% [markdown]
# #### PCA

# %% [markdown]
# 2010

# %%
pca = PCA(n_components=2)
pca_10 = pca.fit_transform(ens10_normMm)
pca_ens10 = pd.DataFrame(data = pca_10, columns = ['Componente_1', 'Componente_2'])
pca_agebs10 = pd.concat([ pca_ens10, ens10[['KMeans_Clusters']]], axis=1)

pca_agebs10.head()
# Out:
#    Componente_1  Componente_2  KMeans_Clusters
# 0      1.495080     -0.320437                5
# 1      1.034925      0.130298                5
# 2      0.755402      0.036821                5
# 3      0.444561     -0.449652                3
# 4      0.444655     -0.312054                0

# %% [markdown]
# 2020

# %%
pca = PCA(n_components=2)
pca_20 = pca.fit_transform(ens20_normMm)
pca_ens20 = pd.DataFrame(data = pca_20, columns = ['Componente_1', 'Componente_2'])
pca_agebs20 = pd.concat([ pca_ens20, ens20[['KMeans_Clusters']]], axis=1)

pca_agebs20.head()
# Out:
#    Componente_1  Componente_2  KMeans_Clusters
# 0      1.439662      0.127247                3
# 1      1.072238      0.291060                3
# 2      1.056304     -0.165785                5
# 3      0.491182      0.085651                5
# 4      0.515551     -0.170837                5

# %% [markdown]
# #### visualizacion

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 6))
color_theme = np.array(["red", "green", "blue", "orange", "pink", "purple"])

# Plot for 2020
ax1.set_xlabel('Componente 1', fontsize=15)
ax1.set_ylabel('Componente 2', fontsize=15)
ax1.set_title('Componentes Principales 2020', fontsize=20)
ax1.scatter(x=pca_agebs20.Componente_1, y=pca_agebs20.Componente_2, c=color_theme[pca_agebs20.KMeans_Clusters], s=10)

# Plot for 2010
ax2.set_xlabel('Componente 1', fontsize=15)
ax2.set_ylabel('Componente 2', fontsize=15)
ax2.set_title('Componentes Principales 2010', fontsize=20)
ax2.scatter(x=pca_agebs10.Componente_1, y=pca_agebs10.Componente_2, c=color_theme[pca_agebs10.KMeans_Clusters], s=10)

plt.tight_layout()  # Adjust the spacing between subplots
plt.show()

# %% [markdown]
# ###comparacion

# %%
print('CLUSTERS 2010')
print('CLUSTER 0: ', cluster10_0)
print('CLUSTER 1: ', cluster10_1)
print('CLUSTER 2: ', cluster10_2)
print('CLUSTER 3: ', cluster10_3)
print('CLUSTER 4: ', cluster10_4)
print('CLUSTER 5: ', cluster10_5)
# Out:
# CLUSTERS 2010
# CLUSTER 0:  ['7714', '7697', '7733', '0543', '044A', '7767']
# CLUSTER 1:  ['7752', '0647', '0558', '7786', '0454', '7729', '7771', '0562']
# CLUSTER 2:  ['0628', '7748', '6025', '0577', '0581', '0505', '0492']
# CLUSTER 3:  ['1005', '1024', '1255']
# CLUSTER 4:  ['7678', '101A', '7451', '7663', '770A', '8089']
# CLUSTER 5:  ['6006', '0435', '0524']

# %%
print('CLUSTERS 2020')
print('CLUSTER 0: ', cluster20_0)
print('CLUSTER 1: ', cluster20_1)
print('CLUSTER 2: ', cluster20_2)
print('CLUSTER 3: ', cluster20_3)
print('CLUSTER 4: ', cluster20_4)
print('CLUSTER 5: ', cluster20_5)
# Out:
# CLUSTERS 2020
# CLUSTER 0:  ['7697', '0543']
# CLUSTER 1:  ['0647', '0558', '0454', '7729', '7771', '7733', '0628', '7748', '6025', '0577']
# CLUSTER 2:  ['044A', '770A', '0562', '7451', '7767', '0581', '0492', '0505']
# CLUSTER 3:  ['6006', '0435']
# CLUSTER 4:  ['1255', '7678', '101A', '8089', '7663']
# CLUSTER 5:  ['1005', '7752', '7714', '1024', '0524', '7786']

# %% [markdown]
# <h2> Mapas </h2>

# %%
from INEGIpy import MarcoGeoestadistico

marco = MarcoGeoestadistico()

# %%
bc_municipios = marco.Municipios(entidades='02')
display(bc_municipios)
# Out:
#                                             geometry cvegeo cve_agee cve_agem  \
# 0  MULTIPOLYGON (((-115.57379 32.65919, -115.5498...  02002       02      002
# 1  MULTIPOLYGON (((-115.86641 32.26873, -115.8584...  02001       02      001
# 2  MULTIPOLYGON (((-115.64233 31.12645, -115.6268...  02006       02      006
# 3  MULTIPOLYGON (((-115.11450 31.80936, -115.1066...  02007       02      007
# 4  MULTIPOLYGON (((-117.10047 32.53656, -117.0992...  02004       02      004
# 5  MULTIPOLYGON (((-117.05342 32.42209, -117.0528...  02005       02      005
# 6  MULTIPOLYGON (((-116.73856 32.56685, -116.7373...  02003       02      003
#
#              nom_agem cve_cab      pob pob_fem pob_mas     viv     nom_cab
# 0            Mexicali    0001  1049792  520544  529248  330500         NaN
# 1            Ensenada    0001   443807  222500  221307  139968    Asientos
# 2         San Quintín    0001   117568   57790   59778   32773         NaN
# 3          San Felipe    0001      NaN     NaN     NaN     NaN  San Felipe
# 4             Tijuana    0001  1922523  953783  968740  577011         NaN
# 5  Playas de Rosarito    0001   126890   62504   64386   38135         NaN
# 6              Tecate    0001   108440   51310   57130   31176         NaN

# %%
bc_localidades = marco.LocalidadesAmanzanadas(entidades = '02', 
                                           municipios = '001')
display(bc_localidades.head(5))
# Out:
#                                             geometry     cvegeo cve_agee  \
# 0  MULTIPOLYGON (((-116.59744 31.91723, -116.5969...  020010001       02
# 1  MULTIPOLYGON (((-116.37305 31.28129, -116.3717...  020010095       02
# 2  MULTIPOLYGON (((-116.58290 32.10414, -116.5828...  020010114       02
# 3  MULTIPOLYGON (((-116.16108 30.97980, -116.1600...  020010118       02
# 4  MULTIPOLYGON (((-116.13264 31.93724, -116.1326...  020010121       02
#
#   cve_agem cve_loc                               nom_loc  ambito     latitud  \
# 0      001    0001                              Ensenada  URBANO  31.8089439
# 1      001    0095                        Ejido Eréndira   RURAL  31.2733236
# 2      001    0114  Francisco Zarco (Valle de Guadalupe)  URBANO  32.0969847
# 3      001    0118         Licenciado Gustavo Díaz Ordaz   RURAL  30.9713356
# 4      001    0121                             La Huerta   RURAL  31.9345175
#
#        longitud altitud     pob     viv cve_carta  estatus     periodo
# 0  -116.5951339    0018  330652  105810    H11B12        1  2015-06-01
# 1  -116.3713950    0016    1711     517    H11B32        1  2015-06-01
# 2  -116.5795778    0343    4334    1339    I11D82        1  2015-06-01
# 3  -116.1544439    0050    1640     473    H11B53        1  2015-06-01
# 4  -116.1327189    0959     110      32    H11B13        1  2015-06-01

# %%
agebs10 = ens10.AGEB.astype(str)
#make it a list 
agebs10 = agebs10.tolist()
agebs10
# Out:
# ['6006',
#  '0435',
#  '0524',
#  '1005',
#  '7714',
#  '7752',
#  '0647',
#  '0558',
#  '7786',
#  '0454',
#  '7697',
#  '7729',
#  '1024',
#  '7771',
#  '7733',
#  '0543',
#  '1255',
#  '7678',
#  '0628',
#  '0562',
#  '044A',
#  '7748',
#  '101A',
#  '6025',
#  '7451',
#  '7663',
#  '0577',
#  '770A',
#  '7767',
#  '0581',
#  '8089',
#  '0505',
#  '0492']

# %%
# podemos usar los valores de una tabla para apoyar en la búsqueda de otros valores cuando no se tenga la clave previamente

cve_concatenada = bc_localidades[bc_localidades.nom_loc == 'Ensenada'].cvegeo.iloc[0]
print('Clave Concatenada de Ensenada: {}'.format(cve_concatenada))
agebs10 = ens10.AGEB.astype(str)
agebs10 = agebs10.tolist()
ens_agebs = marco.AGEBs(agebs=agebs10)
ens_agebs.plot()
# Out:
# Clave Concatenada de Ensenada: 020010001
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[45], line 7
#       5 agebs10 = ens10.AGEB.astype(str)
#       6 agebs10 = agebs10.tolist()
# ----> 7 ens_agebs = marco.AGEBs(agebs=agebs10)
#       8 ens_agebs.plot()
#
# File ~/.local/lib/python3.10/site-packages/INEGIpy/_marco_geoestadistico.py:263, in MarcoGeoestadistico.AGEBs(self, entidades, municipios, localidades, agebs, claves_concatenadas, ambito, as_geodf)
#     261 if claves_concatenadas: claves = [self.__obtener_claves(claves_concatenadas=clave)[0] if len(clave) <= 5 else clave for clave in claves]
#     262 liga, areas_geoestadisticas = self.__liga_y_areas(None, claves, tipo_area, as_geodf)
# --> 263 df = self.__obtener_consulta(liga, areas_geoestadisticas, as_geodf)
#     264 try: df.iloc[:, -5:-1] = df.iloc[:, -5:-1].astype(int)
#     265 except: pass
#
# File ~/.local/lib/python3.10/site-packages/INEGIpy/_marco_geoestadistico.py:83, in MarcoGeoestadistico.__obtener_consulta(self, liga, areas_geoestadisticas, as_gdf, ambito)
#      81     liga_final = liga + area
#      82     if ambito: liga_final = liga_final + ambito.capitalize()[0]
# ---> 83     df = self.__obtener_df(liga_final, as_gdf)
#      84     dfs.append(df)
#      85 c_df = pd.concat(dfs, axis = 0)
#
# File ~/.local/lib/python3.10/site-packages/INEGIpy/_marco_geoestadistico.py:13, in MarcoGeoestadistico.__obtener_df(self, liga, as_gdf)
#      11 def __obtener_df(self, liga, as_gdf):
#      12     req = requests.get(liga)
# ---> 13     assert req.status_code == 200, 'No se encontró información con las parámetros especificados. \n Liga: {}'.format(liga)
#      14     data =  json.loads(req.text)
#      15     if as_gdf:
#
# AssertionError: No se encontró información con las parámetros especificados.
#  Liga: https://gaia.inegi.org.mx/wscatgeo/geo/agebu/

# %%
import geopandas as gpd

# Asignar un color diferente a cada cluster
ens_agebs['color'] = 'blue'
ens_agebs.loc[ens_agebs.cve_ageb.isin(cluster10_0), 'color'] = '0'
ens_agebs.loc[ens_agebs.cve_ageb.isin(cluster10_1), 'color'] = '1'
ens_agebs.loc[ens_agebs.cve_ageb.isin(cluster10_2), 'color'] = '2'
ens_agebs.loc[ens_agebs.cve_ageb.isin(cluster10_3), 'color'] = '3'
ens_agebs.loc[ens_agebs.cve_ageb.isin(cluster10_4), 'color'] = '4'
ens_agebs.loc[ens_agebs.cve_ageb.isin(cluster10_5), 'color'] = '5'

# Plot
ens_agebs.plot(column='color', legend=True)
# Out:
# <Axes: >
